# %% [markdown]
# # COVIS_Project 3D data modeling & vizualization

# %% [markdown]
#  Step one: Edit your data

# %% [markdown]
#  Step two: Use Pandas to read the edited file into Pandas DataFrame

# %% [markdown]
#  Step three: Use Pandas to make a scatter plott that plost the positions on an xy plane and add color using elevations

# %% [markdown]
#  Step four: Plot the same dtaa using 3D vizualization. Use Matplotlib after taking the data into lists.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits import mplot3d

# %% [markdown]
# To understand the data we are going to draw we muct first link it to our Pandas DAtaFrame

# %%
df_bathy = pd.read_csv('actualbathy.csv')
df_bathy
# Out:
#         -35    -25  9.32108797751026
# 0     -35.0 -24.75          9.356787
# 1     -35.0 -24.50          9.392487
# 2     -35.0 -24.25          9.428186
# 3     -35.0 -24.00          9.504512
# 4     -35.0 -23.75          9.448359
# ...     ...    ...               ...
# 19475   5.0   4.00          2.710687
# 19476   5.0   4.25          2.729047
# 19477   5.0   4.50          2.745627
# 19478   5.0   4.75          2.762208
# 19479   5.0   5.00          2.766418
#
# [19480 rows x 3 columns]

# %%
eastlist = list(df_bathy['east']),
northlist = list(df_bathy['north']),
elevationlist = list(df_bathy['elevation'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'east'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-0b8de110ae21> in <module>
# ----> 1 eastlist = list(df_bathy['east']),
#       2 northlist = list(df_bathy['north']),
#       3 elevationlist = list(df_bathy['elevation'])
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2973             if self.columns.nlevels > 1:
#    2974                 return self._getitem_multilevel(key)
# -> 2975             indexer = self.columns.get_loc(key)
#    2976             if is_integer(indexer):
#    2977                 indexer = [indexer]
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
# -> 2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2893         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2894         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'east'

# %%
ax = plt.axes(projection='3d')

xdata= eastlist
ydata= northlist
zdata= elevationlist
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='viridis');
plt.savefig('A10plot.png')
